# %% [markdown]
# <a href="https://colab.research.google.com/github/ladams1204/SportsBookEdge/blob/main/01_data_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nba_api
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.6/322.6 kB 11.8 MB/s eta 0:00:00
# ...

# %%
from nba_api.stats.endpoints import playergamelog
from nba_api.stats.static import players
import pandas as pd

# %%
lebron = players.find_players_by_full_name("LeBron James")[0]
print(lebron)
# Out:
# {'id': 2544, 'full_name': 'LeBron James', 'first_name': 'LeBron', 'last_name': 'James', 'is_active': True}

# %%
game_log = playergamelog.PlayerGameLog(player_id=lebron['id'], season='2025-26')
df = game_log.get_data_frames()[0]
df.head()
# Out:
#   SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0     22025       2544  0022501198  Apr 12, 2026  LAL vs. UTA  W   17    6
# 1     22025       2544  0022501185  Apr 10, 2026  LAL vs. PHX  W   32   10
# 2     22025       2544  0022501170  Apr 09, 2026    LAL @ GSW  W   32   11
# 3     22025       2544  0022501140  Apr 05, 2026    LAL @ DAL  L   39   12
# 4     22025       2544  0022501116  Apr 02, 2026    LAL @ OKC  L   26    3
#
#    FGA  FG_PCT  ...  DREB  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  \
# 0   15   0.400  ...     4    4    6    3    0    4   0   18          14
# 1   16   0.625  ...     6    6   12    4    0    2   1   28          27
# 2   17   0.647  ...     8    8   11    2    1    4   1   26          19
# 3   22   0.545  ...     9    9   15    1    0    4   1   30           1
# 4    7   0.429  ...     6    6    2    1    1    2   1   13         -37
#
#    VIDEO_AVAILABLE
# 0                1
# 1                1
# 2                1
# ...
